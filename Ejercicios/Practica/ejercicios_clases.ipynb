# %% [markdown]
# ## Clases

# %% [markdown]
# [Teoría y ejercicios](https://www.w3schools.com/python/python_classes.asp)

# %% [markdown]
#                                                                 Ejercios para practicar

# %% [markdown]
# Ejercicio 1:
#
# Crea la clase Coche que contenga las siguientes propiedades:
#
# * matrícula
# * marca
# * Combustible
#
# Crea un Objeto

# %%
# introduce tu código
 
      
# print(mi_coche)

# %% [markdown]
# Ejercicio 2:
#
#     Cree una clase de Python llamada Usuario que use el método init y cree un nombre de usuario y una contraseña.
#
#     Crea un objeto usando la clase y un método recuperar_contraseña.

# %%
# introduce tu código

# print (usuario1.recuperar_contrasena())
# Out:
# Usuario: mi_usuario,
# Contraseña: mi_contraseña

# %% [markdown]
# Ejercicio 3:
#
#     Define una clase llamada Perro que tenga  dos atributos, nombre y raza, y un método, ladrar. Luego se crea un objeto perro a partir de esta clase y se accede a sus atributos y métodos.

# %%
# introduce tu código


# print(mi_perro.nombre)  # Output: Fido
# Out:
# Fido
# Guau!

# %% [markdown]
# Ejercicio 4:
#
#     Diseña una clase Libro que contenga atributos como titulo y autor. Implementa tus métodos para añadir tus libros favoritos.

# %%
# introduce tu código
# Out:
# Título: La novia gitana, Autor: Carmen Mola
# Título: El hombre de tiza, Autor: C.J. Tudor

# %% [markdown]
# Ejercicio 5:
#
# Define la clase de la imagen
#
# ![image.png](attachment:image.png)

# %%
# introduce tu código

# %% [markdown]
# ▶   [seinoiculoS :](../Soluciones/Soluciones_clases.py)

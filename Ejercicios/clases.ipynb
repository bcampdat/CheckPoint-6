# %% [markdown]
#                                 Preguntas Teoricas

# %% [markdown]
# ## ***1. ¿Para qué usamos Clases en Python?***
#
#     Las clases nos sirven para poder llevar a un plano abstracto o imaginario, objetos de la vida real; pueden tener atributos (tamaño, nombre, color...), métodos (Modificar algo, borrar algo, o hacer algo en general) y creas objetos de ellos (Osea, creas una nueva instancia de esa clase, con diferentes atributos).

# %% [markdown]
#    ![image.png](attachment:image.png)

# %% [markdown]
# En programación se usa.....
#
# Sintaxis:
# ````
# class NombreClase:
#     def __init__(self, atributos):
#         # código para inicializar la clase con los atributos
#
#     # otros métodos de la clase
# ````
#
#
# Un ejemplo
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 🎯 ***NOTA:***
#
#     Es una convención utilizar la notación CamelCase para los nombres de las clases. Esto es, la primera letra de cada palabra del nombre está en mayúsculas y el resto de letras se mantienen en minúsculas.

# %% [markdown]
# [Clases : ▶](https://youtu.be/9x7RK6mb1uA)

# %% [markdown]
# [Teoría y ejercicios](https://www.w3schools.com/python/python_classes.asp)

# %% [markdown]
# 👍 [EJERCICIOS PARA PRACTICAR :](./Practica/ejercicios_clases.ipynb)

# %% [markdown]
# ## ***2. ¿Qué método se ejecuta automáticamente cuando se crea una instancia de una clase?***
#
# Usando el método [__ init __ ▶](https://youtube.com/shorts/vK8JtizoCpM?si=xe9i0-ZCPtvGY-Uf)
#
# +   También llamado metodo constructor.
# +   Se ejecuta automáticamente cuando creas un objeto a partir de una clase. Su trabajo es "inicializar" los atributos del objeto.
# +   No es obligatorio tener este método en una clase, pero es útil para asignar valores iniciales a los atributos del objeto.
# +   Además, se llama automáticamente al crear un objeto, lo que significa que puedes asignar valores y llamar métodos de la clase cuando creas un objeto.

# %%
# Ejemplo:

class Humano(): #Creamos la clase Humano
    def __init__(self, edad, nombre):       # Definimos el atributo edad y nombre
        self.edad = edad                    # Definimos que el atributo edad, sera la edad asignada
        self.nombre = nombre                # Definimos que el atributo nombre, sera el nombre asignado

Persona1 = Humano(31, "Pedro")              #Instancia

print(Persona1.edad)                       #Imprime el atributo edad
# Out:
# 31

# %% [markdown]
# ## ***3. ¿Qué es un método dunder?***

# %% [markdown]
# En Python, los métodos dunder (abreviatura de «double underscore methods», también conocidos como «métodos mágicos» o «métodos especiales») son métodos especiales que tienen un doble guion bajo (__) al principio y al final de su nombre. Se emplean para definir el comportamiento especial de las clases y sus instancias, y son llamados automáticamente por el intérprete de Python en respuesta a ciertas operaciones.
#
# Los métodos dunder pueden utilizarse para implementar características como la inicialización de objetos, la representación en forma de cadena, la sobrecarga de operadores, la comparación, entre otras.

# %% [markdown]
# [***Métodos Magicos :*** ▶](https://youtube.com/shorts/hKopml-5x3E?si=HpVt47VGy7zPQGwT)
#
# **__ init __**      →   Inicializa un objeto
#
# Crea un nuevo objeto cuando se llama a la instancia de una clase.
#
# ````
# class Car (object):
#
#     def __init__(self):
#         ...
#
#     def __repr__(self):
#         ...
# ````
# **__ new __**   →  Crea un objeto personaliza la creación
#
# **__ del __**   →  Elimina un objeto
#
# ````
#     def __del__(self):
#         print(f'El objeto {self.nombre} ha sido eliminado')
# ````
#
# **__ str __**   →   Método de representación en forma de cadena
#
# ````
#     def __str__(self):
#         return f'Este es un objeto de mi clase'
# ````
#
# **__ repr __**  →   Método de representación del objeto
#
# **__ len __**   →   Devuelve la cantidad de elementos que tiene una lista.
#
# **__ getitem __**   →    Método de indexación

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Ejemplo:

class Humano:
    def __init__(self, nombre, edad):
        self.nombre = nombre
        self.edad = edad

    def __repr__(self):
        return f'{self.nombre} ({self.edad} años)'

    def __add__(self, otro):
        suma_edad = self.edad + otro.edad
        return Humano(f'{self.nombre} y {otro.nombre}', suma_edad)

    def __ne__(self, otro):
        return (self.nombre, self.edad) != (otro.nombre, otro.edad)

# Crear instancias de la clase
persona1 = Humano('Alice', 25)
persona2 = Humano('Bob', 30)

# Ejemplo de uso de los métodos
print(persona1)          # Salida: Alice (25 años)
print(persona1 + persona2) # Salida: Alice y Bob (55 años)
print(persona1 != persona2) # Salida: True

# %% [markdown]
# 👍 [EJERCICIOS PARA PRACTICAR :](./Practica/ejercicios__dunder__.ipynb)
